# %% [markdown]
# [Python, Visually](https://johnfisher-ai.github.io/Python-Visual-Guides/) &nbsp;&rsaquo;&nbsp; [Python from the Start](https://johnfisher-ai.github.io/Python-Visual-Guides/python-from-the-start.html)
#
# # Numbers

# %% [markdown]
# ## What you will be able to do
#
# Do arithmetic with Python's two kinds of number, the exact **int** and the approximate
# **float**, and trust the result even in the cases where it looks wrong. You will be able to say
# why `0.1 + 0.2` is not `0.3`, and what to do about it.

# %% [markdown]
# ## The idea
#
# ### The problem
#
# Counting and measuring are not the same activity, and a language that treats them the same will
# mislead you.
#
# Counting is exact. Three people is three people. There is no such thing as 3.2 of them, and if
# you count the same room twice you get the same answer. Measuring is different. A temperature, a
# weight, a price after tax: each is a reading with a limit to how precisely it can be recorded,
# and that limit is real whether or not you think about it.
#
# Python keeps the two apart, and gives you a different type for each.
#
# ### The two kinds of number
#
# > An **int** is a whole number. It is stored exactly, and it has no upper limit: an int grows
# > to whatever size it needs.
# >
# > A **float** is a number with a decimal point. It is stored as an **approximation**, in a
# > fixed amount of space, and it has both a size limit and a precision limit.
#
# That word **approximation** is the important one.
#
# ### Why a float is an approximation
#
# A float is stored in binary, as a fraction with a power of two underneath it. Some decimal
# numbers fit that scheme perfectly. Most do not.
#
# `0.1` is one that does not. In binary it repeats forever, in the same way that one third
# written as a decimal repeats forever: `0.3333...` never finishes, and if you stop writing you
# have an approximation. Python stops writing. What gets stored is the closest value the format
# can hold, which is very near `0.1` but not equal to it.
#
# Almost always that gap is far too small to matter. Then one day you add two of them, compare
# the total against what you expected, and Python tells you they are not equal. Nothing is
# broken. You are seeing the cost of a fixed-size format, and every language that stores numbers
# this way pays exactly the same cost, including the spreadsheet on your desk.
#
# What you can do is recognize the situation on sight and know the two standard ways around it.
# Both are in this notebook.
#
# ### Where you will meet this
#
# Any money calculation. Any measurement, any average, any percentage. Any total that gets
# compared against another total. the **NumPy** guide onward is built on floats by the million, and every
# statistical result in this library rests on them.
#
# The whole-number side matters too, in a quieter way: division in Python always hands back a
# float, even when the answer is whole, and knowing that saves confusion later.
#
# ### What this notebook covers
#
# - The two types, and how to tell which you have
# - The four operations, and why `/` always produces a float
# - Whole-number division and remainder, with the trap that appears for negatives
# - Powers, and order of operations
# - Why `0.1 + 0.2` is not `0.3`, shown at twenty decimal places
# - How to compare floats safely, and how to round for display
# - Why `round(2.5)` gives `2`
# - Four errors, including the one that does not raise
#
# ### A first look
#
# Before any of the detail, here is the whole idea in a few lines. There is nothing to run yet:
# read it, and read the output underneath it. Everything from Setup onward is where you start
# running things, and the rest of the notebook takes this apart piece by piece.
#
# ```python
# print(7, type(7))
# print(7.0, type(7.0))
# ```
#
# ```
# 7 <class 'int'>
# 7.0 <class 'float'>
# ```
#
# `7` and `7.0` are the same quantity and different types. That distinction decides what happens
# when you divide, round, or compare, so it is worth noticing early.

# %% [markdown]
# ## Setup
#
# One import, from the standard library. `math` comes with Python; there is nothing to install.

# %%
import math

print("Ready.")
# Out:
# Ready.

# %% [markdown]
# ## Worked examples
#
# ### The four operations
#
# Addition, subtraction and multiplication behave the way you expect.

# %%
print(3 + 4)
print(10 - 4)
print(6 * 7)
# Out:
# 7
# 6
# 42

# %% [markdown]
# Division is the one to look at. `/` **always** gives a float, even when the answer is whole.

# %%
print(7 / 2)
print(6 / 3)          # exactly 2, but still a float
print(type(6 / 3))
# Out:
# 3.5
# 2.0
# <class 'float'>

# %% [markdown]
# This is a deliberate change from Python 2, where `6 / 3` gave an int and `7 / 2` quietly gave
# `3`. If you find old code doing division and getting whole numbers, that is why.
#
# ### Whole-number division and remainder
#
# When you want the whole part and the leftover, use `//` and `%`.

# %%
print(7 // 2)         # how many whole 2s fit in 7
print(7 % 2)          # what is left over
# Out:
# 3
# 1

# %% [markdown]
# These two go together. A common use is splitting one number into units.

# %%
total_minutes = 500

hours = total_minutes // 60
minutes = total_minutes % 60

print(total_minutes, "minutes is", hours, "hours and", minutes, "minutes")
# Out:
# 500 minutes is 8 hours and 20 minutes

# %% [markdown]
# `%` is also the usual test for divisibility, because a remainder of zero means it divided
# evenly.

# %%
print(10 % 2)         # 0, so 10 is even
print(11 % 2)         # 1, so 11 is odd
# Out:
# 0
# 1

# %% [markdown]
# ### A trap with negative numbers
#
# `//` does not cut the decimal off. It rounds **down**, toward the more negative number, which
# for negatives is away from zero.

# %%
print(7 / 2, 7 // 2)
print(-7 / 2, -7 // 2)      # not -3
# Out:
# 3.5 3
# -3.5 -4

# %% [markdown]
# `-7 / 2` is `-3.5`, and the next whole number down from `-3.5` is `-4`, not `-3`.
#
# If you want the decimal simply cut off, that is `int()`, which always moves toward zero.

# %%
print(int(-3.5), -7 // 2)   # these disagree, on purpose
# Out:
# -3 -4

# %% [markdown]
# Both are correct; they answer different questions. Pick the one you mean.
#
# ### Powers
#
# `**` raises to a power. A fractional power is a root.

# %%
print(2 ** 10)
print(2 ** 0.5)       # the square root of 2
print(math.sqrt(2))   # the same thing, said more clearly
# Out:
# 1024
# 1.4142135623730951
# 1.4142135623730951

# %% [markdown]
# ### Order of operations
#
# Python follows the usual rules: powers first, then multiply and divide, then add and subtract.

# %%
print(2 + 3 * 4)      # 14, not 20
print((2 + 3) * 4)    # 20
# Out:
# 14
# 20

# %% [markdown]
# When an expression gets long, break it across lines **inside parentheses**. Python treats
# everything between an open parenthesis and its close as one statement, so you can put the line
# breaks wherever they read best.

# %%
total = (
    1200            # rent
    + 340           # food
    + 95            # transport
    + 60            # phone
)

print("monthly total:", total)
# Out:
# monthly total: 1695

# %% [markdown]
# ### Floats are approximations
#
# This is the part that catches everyone.

# %%
print(0.1 + 0.2)
# Out:
# 0.30000000000000004

# %% [markdown]
# That is not a bug in Python, and every language that stores numbers this way does the same
# thing. The cause is that `0.1` cannot be written exactly in binary, any more than one third can
# be written exactly as a decimal. You get the closest available value.
#
# Ask for more digits and the stored value shows itself.

# %%
print(format(0.1, ".20f"))
print(format(0.2, ".20f"))
print(format(0.1 + 0.2, ".20f"))
# Out:
# 0.10000000000000000555
# 0.20000000000000001110
# 0.30000000000000004441

# %% [markdown]
# The tiny excess was there in `0.1` all along. Adding made it visible.
#
# ### So do not compare floats with `==`
#
# The comparison you would naturally write is the one that fails.

# %%
print(0.1 + 0.2 == 0.3)
# Out:
# False

# %% [markdown]
# Compare with a tolerance instead. `math.isclose` asks whether two numbers are near enough,
# which is almost always the real question.

# %%
print(math.isclose(0.1 + 0.2, 0.3))
# Out:
# True

# %% [markdown]
# For **display**, round to the number of decimals you actually want.

# %%
print(round(0.1 + 0.2, 2))
# Out:
# 0.3

# %% [markdown]
# Rounding for display and comparing with a tolerance are different jobs. Rounding changes the
# number you show. `math.isclose` leaves the number alone and changes the question.
#
# ### `round` does not do what you were taught
#
# Python rounds a halfway value to the **even** neighbor, not always upward.

# %%
print(round(0.5), round(1.5), round(2.5), round(3.5))
# Out:
# 0 2 2 4

# %% [markdown]
# `2.5` rounds to `2` and `3.5` rounds to `4`. This is the standard used across science and
# finance, because always rounding halves upward introduces a small bias that accumulates over
# many values.
#
# It surprises people, and it is not a mistake.
#
# ### Ints are unbounded
#
# Most languages have a largest integer. Python does not: an int grows to whatever it needs.

# %%
print(2 ** 200)
print("2 ** 1000 has", len(str(2 ** 1000)), "digits")
# Out:
# 1606938044258990275541962092341162602522202993782792835301376
# 2 ** 1000 has 302 digits

# %% [markdown]
# Floats do have a limit, because they are stored in a fixed amount of space. You meet it in
# Common errors below.
#
# ### Converting between them
#
# `int()` and `float()` convert, and `int()` cuts toward zero rather than rounding.

# %%
print(int(3.9), int(-3.9))    # cut toward zero, not rounded
print(float(3))
print(int("42"))              # text that looks like a whole number
print(float("3.5"))
# Out:
# 3 -3
# 3.0
# 42
# 3.5

# %% [markdown]
# ## Your turn
#
# Five tasks. Write your answer in the cell under each and run it.
#
# Try each one before you look at an answer. Reading a solution teaches you much less than
# getting there yourself, even slowly.
#
# When you are ready: [**open the solutions notebook**](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/03-numbers-solutions.ipynb).
#
# **1.** A film runs `500` minutes over three parts. Print how many whole hours and leftover
# minutes that is, using `//` and `%`.

# %%
# your code here

# %% [markdown]
# **2.** A meal costs `47.50` and you want to add a 15 percent tip. Print the tip rounded to two
# decimal places, then the total rounded to two decimal places.

# %%
# your code here

# %% [markdown]
# **3.** Print the result of `0.1 * 3 == 0.3`, then print `math.isclose(0.1 * 3, 0.3)`. One line
# each, so you can see the two answers disagree.

# %%
# your code here

# %% [markdown]
# **4.** Print `2 ** 64`, then print how many digits that number has. `len(str(...))` will tell
# you.

# %%
# your code here

# %% [markdown]
# **5.** Print `int(-7 / 2)` and `-7 // 2` on separate lines. They give different answers. Add a
# comment saying which one rounds down and which one cuts toward zero.

# %%
# your code here

# %% [markdown]
# ## Common errors
#
# Each cell below is run on purpose so you can see the real message.
#
# ### ZeroDivisionError: you divided by zero
#
# Arithmetic that has no answer stops the program rather than inventing one.

# %%
print(10 / 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(10 / 0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# `division by zero` is exactly what it says. `//` and `%` fail the same way for the same reason.
#
# When the divisor comes from data rather than from you, check it first: `if count != 0:` before
# dividing is the usual fix.

# %% [markdown]
# ### ValueError: that text is not a whole number
#
# `int()` accepts text, but only text that already looks like an int.

# %%
print(int("3.5"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(int("3.5"))
#
# ValueError: invalid literal for int() with base 10: '3.5'

# %% [markdown]
# `invalid literal for int() with base 10: '3.5'` means Python read the text, found a decimal
# point, and refused to guess whether you wanted `3` or `4`.
#
# Convert in two steps when the text has a decimal point, and decide the rounding yourself:

# %%
print(int(float("3.5")))     # cut toward zero, giving 3
print(round(float("3.5")))   # round to even, giving 4
# Out:
# 3
# 4

# %% [markdown]
# ### OverflowError: too large for a float
#
# Ints grow as needed. Floats do not.

# %%
print(10.0 ** 400)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(10.0 ** 400)
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# `Result too large` means the number no longer fits in the fixed space a float uses. The largest
# is a little under `1.8e308`.
#
# The same calculation in whole numbers is fine, because ints have no ceiling:

# %%
print("10 ** 400 has", len(str(10 ** 400)), "digits")
# Out:
# 10 ** 400 has 401 digits

# %% [markdown]
# ### TypeError: arithmetic on something that is not a number
#
# Text that looks like a number is still text.

# %%
print(2 ** "10")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(2 ** "10")
#
# TypeError: unsupported operand type(s) for ** or pow(): 'int' and 'str'

# %% [markdown]
# `unsupported operand type(s) for ** or pow(): 'int' and 'str'` means one side was text. Convert
# it first with `int()` or `float()`.
#
# This is the same family of error as joining text and a number with `+` in the **Running Python** notebook. Python
# does not convert types behind your back.

# %% [markdown]
# ## Recap
#
# - `int` is a whole number and is exact; `float` has a decimal point and is an approximation.
# - `/` always gives a float. `//` gives the whole part, `%` gives the remainder.
# - `//` rounds down and `int()` cuts toward zero, which differ for negative numbers.
# - `0.1 + 0.2` is not `0.3`, so compare floats with `math.isclose` and round only for display.
# - `round` sends a halfway value to the even neighbor, so `round(2.5)` is `2`.
# - Ints have no upper limit; floats stop a little under `1.8e308`.

# %% [markdown]
# ## What is next
#
# The **Strings** notebook, where text gets the same treatment: how to slice it, build it with
# f-strings, and why the methods give you a new string rather than changing the one you have.

# %% [markdown]
# ---
#
# &#8592; **Previous:** [Values and Variables](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/02-values-and-variables.ipynb)  &nbsp;·&nbsp;  [Python from the Start Notebooks](https://johnfisher-ai.github.io/Python-Visual-Guides/python-from-the-start.html)  &nbsp;·&nbsp;  **Next:** [Strings](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/04-strings.ipynb) &#8594;
