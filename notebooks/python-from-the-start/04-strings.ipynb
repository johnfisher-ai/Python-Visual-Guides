# %% [markdown]
# [Python, Visually](https://johnfisher-ai.github.io/Python-Visual-Guides/) &nbsp;&rsaquo;&nbsp; [Python from the Start](https://johnfisher-ai.github.io/Python-Visual-Guides/python-from-the-start.html)
#
# # Strings

# %% [markdown]
# ## What you will be able to do
#
# Work with text, which Python calls a **string**: pull pieces out of it, build new text from
# values you have, and clean up text that arrived messy. You will also be able to say why a
# string method never changes the string you gave it.

# %% [markdown]
# ## The idea
#
# ### The problem
#
# Almost everything that crosses the boundary of a program is text.
#
# Files are text. Web pages are text. Form fields, database columns, command output, log lines,
# API responses, anything a person types: all text. Even things that look like numbers arrive as
# text, and stay text until you convert them. The `"42"` typed into a box is not the number 42,
# and adding 1 to it will not give you 43.
#
# So a large share of real programming is not calculating. It is receiving text, finding the part
# you want, reshaping it, and sending it back out.
#
# ### What a string is
#
# > A **string** is a **sequence of characters in order**. Each character occupies a numbered
# > position, counted from `0`, and that number is called its **index**.
# >
# > A string is also **immutable**: once created it can never be altered. Every operation that
# > appears to change a string actually builds a new one and returns it.
#
# Both halves of that definition drive everything in this notebook.
#
# ### Why a sequence
#
# Because a string is ordered and positioned, you can reach into it. Take the first character.
# Take characters three through seven. Take the last four. Walk through it one character at a
# time. Reverse it.
#
# That is what handling text means in practice: pulling the year out of a date, taking the
# extension off a filename, trimming stray spaces off a column imported from a spreadsheet,
# splitting one line into fields.
#
# ### Why immutable
#
# This one surprises people, and it is the source of the most common mistake in this notebook.
#
# `text.upper()` does not shout at `text`. It builds a **new** string that is the uppercase
# version and hands it back. If you do not assign that result to something, nothing appears to
# have happened, and beginners conclude the method is broken.
#
# The same rule explains why you cannot repair one character in place. There is no editing a
# string; there is only building a different one. The **Lists** notebook introduces lists, which work the
# opposite way, and the contrast is worth carrying with you.
#
# ### Where you will meet this
#
# Reading and cleaning files, which is the **Files** guide. Talking to web services, which is the **APIs and JSON** guide. The
# pandas `.str` tools in the **Pandas** guide are these same operations applied to a whole column at once.
# Before any of that, the **Regular Expressions** notebook in this guide picks up where these methods stop.
#
# ### What this notebook covers
#
# - Quotes, and text that spans several lines
# - Indexing from either end, and slicing runs of characters
# - Why slicing forgives a position past the end and indexing does not
# - `repr`, for seeing exactly what a string contains
# - f-strings, for building text out of values, with formatting
# - The methods that clean and reshape text, and why each returns a new string
# - Splitting into a list and joining back again
# - Escape characters, and raw strings, which the **Regular Expressions** notebook depends on
# - Four errors, starting with the one immutability causes
#
# ### A first look
#
# Before any of the detail, here is the whole idea in a few lines. There is nothing to run yet:
# read it, and read the output underneath it. Everything from Setup onward is where you start
# running things, and the rest of the notebook takes this apart piece by piece.
#
# ```python
# city = "Philadelphia"
#
# print(city)
# print(len(city), "characters")
# print(city[0], "is the character at index 0")
# ```
#
# ```
# Philadelphia
# 12 characters
# P is the character at index 0
# ```
#
# `len` counts the characters. `city[0]` means "the character at index 0", and square brackets
# after a name are how you always ask for one.
#
# Indexes start at **0**, not 1. The first character is at index 0, the second at index 1, and
# in a twelve-character word the last is at index 11, not 12. That gap of one between "first"
# and "zero" is the most common source of small mistakes early on, so it is worth saying the
# index out loud while you are learning: index zero is `P`.

# %% [markdown]
# ## Setup
#
# Nothing to import. Text is built into Python.

# %%
# This notebook uses no libraries.
print("Ready.")
# Out:
# Ready.

# %% [markdown]
# ## Worked examples
#
# ### Making a string
#
# Single and double quotes do exactly the same thing. Having both means you can put one kind
# inside the other without any fuss.

# %%
print('single quotes')
print("double quotes")
print("she said 'hello'")
print('it costs $5, and it is worth it')
# Out:
# single quotes
# double quotes
# she said 'hello'
# it costs $5, and it is worth it

# %% [markdown]
# Pick whichever avoids the escaping. For text longer than a line, use three quotes and the line
# breaks are kept.

# %%
note = """Dear reader,

This is a string that spans lines.
The line breaks are part of it."""

print(note)
# Out:
# Dear reader,
#
# This is a string that spans lines.
# The line breaks are part of it.

# %% [markdown]
# ### Indexing from either end
#
# A positive index counts from the left, starting at 0. A **negative index** counts from the
# right, starting at -1 for the last character. Negative indexes save you writing
# `city[len(city) - 1]` every time you want the end.

# %%
city = "Philadelphia"

print(city[0])      # first
print(city[1])      # second
print(city[-1])     # last
print(city[-2])     # second from last
# Out:
# P
# h
# a
# i

# %% [markdown]
# ### Slicing: taking a run of characters
#
# `city[start:end]` gives you everything from `start` up to **but not including** `end`.
#
# That exclusive end is deliberate, and it is worth getting used to rather than fighting.

# %%
print(city[0:4])
print(city[4:8])
# Out:
# Phil
# adel

# %% [markdown]
# The reason it is convenient: the end of one slice is the start of the next, with no `+ 1`
# anywhere, and `end - start` is the length you get.

# %%
print(city[0:4] + city[4:12])   # the two halves rejoin exactly
print(len(city[4:8]), "characters, which is 8 - 4")
# Out:
# Philadelphia
# 4 characters, which is 8 - 4

# %% [markdown]
# Leave a side blank and Python fills in the obvious end.

# %%
print(city[:4])     # from the beginning
print(city[4:])     # to the end
print(city[-3:])    # the last three
print(city[:])      # the whole thing
# Out:
# Phil
# adelphia
# hia
# Philadelphia

# %% [markdown]
# A third number is a **step**. A step of `-1` walks the string backward, which is the usual
# way to reverse text.

# %%
print(city[::2])    # every second character
print(city[::-1])   # backward
# Out:
# Piaepi
# aihpledalihP

# %% [markdown]
# ### Seeing exactly what is in a string
#
# `print` is for a person reading the output, so it shows text the way it is meant to be read.
# That is usually what you want, and it is a problem when you are trying to work out what a value
# actually contains.
#
# `repr` is the other view. It shows a value **the way you would type it in code**: quotes
# included, and with characters like a tab or a new line written as `\t` and `\n` instead of
# being acted on.

# %%
value = "  hi\n"

print(value)          # how it reads
print(repr(value))    # what it actually is
# Out:
#   hi
#
# '  hi\n'

# %% [markdown]
# The first line looks like `hi` with some space, followed by a blank line, and you cannot tell
# how much space or where the blank line came from. The second says precisely: two spaces, `hi`,
# then a new line character.
#
# Use `repr` whenever the question is "what is really in there?". It is the fastest way to see:
#
# - spaces at the start or end, which are invisible otherwise
# - an empty string, which prints as nothing at all
# - a `\n` or `\t` that is being acted on rather than shown
#
# This also settles something left open in the **Running Python** notebook. A bare last line displays itself, and
# there the examples were numbers like `7 * 6`, which look identical whichever view you use.
# Text is where the two come apart: a bare last line shows the `repr`, with quotes, while
# `print` shows the text without them.

# %%
city = "Philadelphia"

print(city)     # print: no quotes
city            # bare last line: repr, with quotes
# Out:
# Philadelphia
# 'Philadelphia'

# %% [markdown]
# ### Slicing is forgiving, indexing is not
#
# Ask for a single index past the end and Python stops with an error, which you will see in
# Common errors. Ask for a **slice** past the end and it quietly gives you whatever was there.

# %%
print(repr(city[0:99]))   # more than exists, no complaint
print(repr(city[99:]))    # nothing there at all, an empty string
# Out:
# 'Philadelphia'
# ''

# %% [markdown]
# This is `repr` earning its keep: without the quotes, the second line would be an empty
# output and you could not tell whether anything came back at all.
#
# This difference matters: a slice that silently returns nothing is a common reason a program
# produces empty output instead of an error.

# %% [markdown]
# ### Building text from values
#
# `+` joins strings and `*` repeats one.

# %%
print("Phil" + "adelphia")
print("-" * 30)
# Out:
# Philadelphia
# ------------------------------

# %% [markdown]
# For anything with a value in it, use an **f-string**. Put `f` before the quote and any name in
# braces is replaced by its value.

# %%
name = "Ada"
age = 36

print(f"{name} is {age} years old")
# Out:
# Ada is 36 years old

# %% [markdown]
# Braces can hold a whole expression, not only a name.

# %%
print(f"next year {name} will be {age + 1}")
print(f"{name} in capitals is {name.upper()}")
# Out:
# next year Ada will be 37
# Ada in capitals is ADA

# %% [markdown]
# A colon inside the braces controls formatting. These two are worth memorizing.

# %%
pi = 3.14159
population = 1603797

print(f"pi to two places: {pi:.2f}")
print(f"with thousands separators: {population:,}")
# Out:
# pi to two places: 3.14
# with thousands separators: 1,603,797

# %% [markdown]
# `{pi=}` prints the name and the value together, which is the fastest way to check what a
# variable holds while you are working.

# %%
print(f"{pi=}")
print(f"{population=}")
# Out:
# pi=3.14159
# population=1603797

# %% [markdown]
# ### The quiet mistake: forgetting the f
#
# This one does not raise an error. It prints the braces.

# %%
name = "Ada"

print("Hello, {name}")     # no f, so no substitution
print(f"Hello, {name}")    # with the f
# Out:
# Hello, {name}
# Hello, Ada

# %% [markdown]
# If your output contains literal braces, this is why. There is no error message to lead you
# there, so it is worth recognizing on sight.

# %% [markdown]
# ### Methods: cleaning and changing text
#
# A method is an operation the string performs on itself, reached with a dot.

# %%
city = "Philadelphia"

print(city.upper())
print(city.lower())
print(city.replace("Philadelphia", "Pittsburgh"))
# Out:
# PHILADELPHIA
# philadelphia
# Pittsburgh

# %% [markdown]
# `strip()` removes whitespace from both ends, which is most of what cleaning up input means.

# %%
messy = "   Ada Lovelace \n"

print(repr(messy))
print(repr(messy.strip()))
# Out:
# '   Ada Lovelace \n'
# 'Ada Lovelace'

# %% [markdown]
# ### None of that changed the original
#
# This is immutability, and it is the point of the section.

# %%
city = "Philadelphia"

city.upper()          # this result is thrown away
print(city)           # unchanged

city = city.upper()   # keep it by assigning it
print(city)
# Out:
# Philadelphia
# PHILADELPHIA

# %% [markdown]
# Every string method **returns a new string** and leaves the original alone. If you do not
# assign the result, nothing appears to happen.
#
# This is the most common confusion in this notebook, and it is the same idea as the **Values and Variables** notebook: the
# name has to be pointed at the new value.

# %% [markdown]
# ### Splitting and joining
#
# `split` breaks text into a list. `join` puts a list back together.

# %%
line = "name,age,city"

fields = line.split(",")
print(fields)
print(len(fields), "fields")
# Out:
# ['name', 'age', 'city']
# 3 fields

# %%
print(" | ".join(fields))
print("".join(fields))
# Out:
# name | age | city
# nameagecity

# %% [markdown]
# The string you call `join` on is the **glue** placed between the pieces. Writing the separator first reads backwards until you have used
# it a few times.
#
# Called with nothing, `split` breaks on any run of whitespace, which is what you usually want
# for a sentence.

# %%
print("the  quick   brown fox".split())
# Out:
# ['the', 'quick', 'brown', 'fox']

# %% [markdown]
# ### Searching
#
# `in` answers whether something appears. `find` answers where.

# %%
city = "Philadelphia"

print("delp" in city)
print(city.find("delp"))
print(city.find("xyz"))     # not found
# Out:
# True
# 5
# -1

# %% [markdown]
# `find` returns `-1` when there is no match rather than raising an error. Test for `-1`, and be
# careful not to treat it as a real index, because `-1` is itself a valid index meaning the
# last character.

# %%
print(city.startswith("Phil"))
print(city.endswith("phia"))
print(city.count("a"))
# Out:
# True
# True
# 2

# %% [markdown]
# ### A method that will surprise you
#
# `title()` capitalizes the first letter of every word. Its idea of where a word starts includes
# after an apostrophe.

# %%
print("ada lovelace".title())
print("don't stop".title())
# Out:
# Ada Lovelace
# Don'T Stop

# %% [markdown]
# `Don'T Stop` is wrong, so avoid `title()` on names and anything with
# apostrophes. Capitalizing deliberately is safer.

# %% [markdown]
# ### Backslashes, and turning them off
#
# A backslash starts an escape: `\n` is a new line, `\t` a tab, and `\\` a single backslash.

# %%
print("first\nsecond")
print("a\tb")
print("a single backslash: \\")
# Out:
# first
# second
# a	b
# a single backslash: \

# %% [markdown]
# When you want the backslashes left alone, put `r` before the quote for a **raw string**.

# %%
print("C:\name\table")     # \n and \t become a newline and a tab
print(r"C:\name\table")    # left exactly as written
# Out:
# C:
# ame	able
# C:\name\table

# %% [markdown]
# Raw strings matter more than they look right now. The **Regular Expressions** notebook is full of patterns written with
# backslashes, and they are always written as raw strings for exactly this reason.

# %% [markdown]
# ### Where string methods stop
#
# Everything above needs you to know the exact text you are looking for. Real questions are
# usually vaguer than that: any four digits, a word at the start of a line, a phone number in
# either format.

# %%
log = "2026-09-04 ERROR disk full"

print(log.startswith("2026"))     # fine if you know the year
print(log.find("ERROR"))          # fine if you know the word
# Out:
# True
# 11

# %% [markdown]
# Asking for *any* date, rather than this one, is where string methods stop and the **Regular Expressions** notebook begins.

# %% [markdown]
# ## Your turn
#
# Six tasks. Write your answer in the cell under each and run it.
#
# Try each one before you look at an answer. Reading a solution teaches you much less than
# getting there yourself, even slowly.
#
# When you are ready: [**open the solutions notebook**](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/04-strings-solutions.ipynb).
#
# **1.** Put your own city in a name called `home`. Print its length, its first character, and
# its last character.

# %%
# your code here

# %% [markdown]
# **2.** Using `home`, print the first three characters and the last three characters, each on
# its own line.

# %%
# your code here

# %% [markdown]
# **3.** The string `"  Ada Lovelace  "` has spaces on both ends. Clean it up and print it with
# `repr` so you can see the quotes and prove the spaces are gone.

# %%
# your code here

# %% [markdown]
# **4.** With `first = "Ada"` and `last = "Lovelace"`, use an f-string to print
# `Ada Lovelace has 11 letters`. Count the letters in code, not by hand, and do not count the
# space.

# %%
# your code here

# %% [markdown]
# **5.** Split `"red,green,blue"` on the comma, then join the pieces back together separated by
# `" and "`.

# %%
# your code here

# %% [markdown]
# **6.** Print `"racecar"` reversed, then print `True` or `False` for whether it reads the same
# backward as forward. Do it with a slice, in one comparison.

# %%
# your code here

# %% [markdown]
# ## Common errors
#
# Each cell below is run on purpose so you can see the real message.
#
# ### TypeError: you cannot change a string in place
#
# This is immutability meeting the assignment you would naturally write.

# %%
city = "Philadelphia"
city[0] = "F"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 city = "Philadelphia"
# ----> 2 city[0] = "F"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# `'str' object does not support item assignment` means exactly what it says. A string cannot be
# edited; you build a new one.

# %%
city = "Philadelphia"
city = "F" + city[1:]     # take everything after the first character
print(city)
# Out:
# Fhiladelphia

# %% [markdown]
# ### IndexError: past the end
#
# Asking for a position that does not exist stops the program.

# %%
city = "Philadelphia"
print(city[99])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 city = "Philadelphia"
# ----> 2 print(city[99])
#
# IndexError: string index out of range

# %% [markdown]
# `string index out of range` means the position is beyond the last character. Valid positions
# run from `0` to `len(city) - 1`, which is `0` to `11` here.
#
# Note the contrast with slicing above, which returns an empty string instead of complaining. It
# is worth remembering which one is silent.

# %% [markdown]
# ### AttributeError: that method belongs to something else
#
# `append` adds to a list. Strings cannot be added to, so they do not have it.

# %%
city = "Philadelphia"
city.append("!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 2
#       1 city = "Philadelphia"
# ----> 2 city.append("!")
#
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# `'str' object has no attribute 'append'` is the error you get whenever you call a method the
# value does not have, usually because you thought it was a different type.
#
# `dir(city)` lists everything a string can actually do, and `help(str.replace)` explains one of
# them.

# %% [markdown]
# ### ValueError: index cannot report failure
#
# `find` returns `-1` when there is no match. `index` does the same search but raises instead.

# %%
city = "Philadelphia"
print(city.index("xyz"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 city = "Philadelphia"
# ----> 2 print(city.index("xyz"))
#
# ValueError: substring not found

# %% [markdown]
# `substring not found` is the same situation `find` reports quietly. Use `find` when a miss is
# expected and normal; use `index` when a miss means something has gone wrong and you want it to
# stop.

# %% [markdown]
# ## Recap
#
# - A string is characters in order, reached by position from `0`, or from the end with `-1`.
# - `text[start:end]` excludes the end, so the pieces of consecutive slices fit together exactly.
# - Indexing past the end raises; slicing past the end quietly returns what is there.
# - f-strings build text from values, with `:.2f` and `:,` for formatting and `{x=}` for checking.
# - Methods return a **new** string, so `text.upper()` does nothing unless you assign the result.
# - Raw strings, written `r"..."`, leave backslashes alone, which the **Regular Expressions** notebook relies on.

# %% [markdown]
# ## What is next
#
# The **Regular Expressions** notebook, which picks up exactly where `find` and `replace` stop: describing the shape of the text you want rather than its exact characters.

# %% [markdown]
# ---
#
# &#8592; **Previous:** [Numbers](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/03-numbers.ipynb)  &nbsp;·&nbsp;  [Python from the Start Notebooks](https://johnfisher-ai.github.io/Python-Visual-Guides/python-from-the-start.html)  &nbsp;·&nbsp;  **Next:** [Regular Expressions](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/05-regular-expressions.ipynb) &#8594;
