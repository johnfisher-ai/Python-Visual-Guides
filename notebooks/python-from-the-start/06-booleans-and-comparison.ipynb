# %% [markdown]
# [Python, Visually](https://johnfisher-ai.github.io/Python-Visual-Guides/) &nbsp;&rsaquo;&nbsp; [Python from the Start](https://johnfisher-ai.github.io/Python-Visual-Guides/python-from-the-start.html)
#
# # Booleans and Comparison

# %% [markdown]
# ## What you will be able to do
#
# Ask questions in Python and understand the answers, which are **booleans**, `True` and `False`.
# That includes the answers that are not booleans at all, and knowing which values Python treats
# as true. You will also be able to say what `is` does and why it is almost never what you want.

# %% [markdown]
# ## The idea
#
# ### The problem
#
# Every program so far has run straight through, top to bottom, doing the same thing on every
# run. That is a very short list of useful programs.
#
# Real work is full of decisions. Charge shipping, but only under fifty dollars. Flag the sensor
# reading, but only if it is outside the expected range. Show the reminder, but only when no
# phone number was given. Keep the row, but only if the date is inside the study window.
#
# Each of those hangs on a question with a yes or no answer. Before a program can act on such a
# question, the language needs a way to represent the answer.
#
# ### What a boolean is
#
# > A **boolean** is a value with exactly two possibilities, written `True` and `False` with
# > capital letters. Comparisons produce booleans, and `if` statements consume them.
#
# You will rarely type `True` or `False` yourself. They arrive as the result of a comparison: is
# this smaller than that, are these two equal, is this name in that list.
#
# ### The part that is not obvious
#
# If that were all, this notebook would be one page. Three things complicate it, and each one
# causes real bugs.
#
# **Any value can be used as a condition.** Python does not require an actual boolean. An `if`
# will accept a number, a string, a list, anything at all, and decide for itself whether it counts
# as true. The rule for which values count as false is short and worth memorizing, and it is why
# `if m:` worked in the **Regular Expressions** notebook.
#
# **`and` and `or` do not return booleans.** They hand back one of the values you gave them. That
# sounds like a technicality and turns out to be useful, because it produces the standard way to
# supply a fallback when a value is missing.
#
# **There are two different ways to ask whether two things are "the same".** `==` compares
# values. `is` compares identity, asking whether two names point at the very same object. They
# answer different questions, they disagree in ways that look arbitrary until you know the model
# from the **Values and Variables** notebook, and choosing the wrong one produces a bug that is hard to see.
#
# ### Where you will meet this
#
# The **Conditionals** notebook turns these answers into branching code, and the **Loops** notebook uses them to filter as it
# loops. Beyond this guide, every row you keep or drop from a dataset, every validation check,
# and every test in the **Testing and Packaging** guide rests on exactly this.
#
# ### What this notebook covers
#
# - The six comparisons, and comparing text
# - Chained comparison, which reads like mathematics
# - `and`, `or` and `not`
# - Truthiness: which values count as false, and the two that catch everyone
# - Why `and` and `or` return a value rather than a boolean
# - `is` against `==`, and the one place `is` is the right choice
# - `in` for membership, and `None` as a value
# - Three errors, one of which does not raise at all
#
# Start with a comparison and what it produces.

# %%
print(3 < 5)
print(3 > 5)
print(type(3 < 5))
# Out:
# True
# False
# <class 'bool'>

# %% [markdown]
# `3 < 5` is not a statement of fact you are making. It is a question Python answers, and the
# answer is a value you can store, print, or act on.

# %% [markdown]
# ## Setup
#
# Nothing to import.

# %%
# This notebook uses no libraries.
print("Ready.")
# Out:
# Ready.

# %% [markdown]
# ## Worked examples
#
# ### The comparisons
#
# Six of them, and only the first two are unfamiliar in shape.
#
# | Written | Asks |
# |---|---|
# | `==` | are these equal |
# | `!=` | are these different |
# | `<` `>` | less than, greater than |
# | `<=` `>=` | less than or equal, greater or equal |
#
# `==` has two equals signs because one equals sign already means assignment, which the **Values and Variables** notebook
# covered.

# %%
print(7 == 7)
print(7 != 7)
print(7 <= 7)
print(7 == 7.0)     # same value, different types
# Out:
# True
# False
# True
# True

# %% [markdown]
# `7 == 7.0` is `True` because `==` compares **values**. An int and a float can hold the same
# quantity, and Python says so.
#
# ### Comparing text
#
# Text compares alphabetically, but it is the character codes doing the work, and every capital
# letter sorts before every lowercase one.

# %%
print("apple" < "banana")
print("Apple" < "apple")
print("Zebra" < "apple")     # a capital Z before a lowercase a
# Out:
# True
# True
# True

# %% [markdown]
# `"Zebra" < "apple"` is `True`, which is almost never what a person means by alphabetical.
# Compare `text.lower()` on both sides when you want the human answer.

# %%
print("Zebra".lower() < "apple".lower())
# Out:
# False

# %% [markdown]
# ### Chaining, which reads the way you would say it
#
# Python lets you write a range check the way it appears in mathematics. Most languages do not.

# %%
age = 7

print(0 < age < 18)
print(0 < 70 < 18)
# Out:
# True
# False

# %% [markdown]
# `0 < age < 18` means both comparisons, and it only evaluates `age` once. Written out it would
# be `0 < age and age < 18`.
#
# ### and, or, not
#
# These combine answers.

# %%
print(True and False)     # both must hold
print(True or False)      # either will do
print(not True)           # flip it
# Out:
# False
# True
# False

# %%
temperature = 71
raining = False

print(temperature > 65 and not raining)
# Out:
# True

# %% [markdown]
# ### Truthiness: values that count as true or false
#
# An `if` does not need an actual boolean. Every value in Python counts as one, and the rule is
# short enough to memorize.
#
# **These are false.** Everything else is true.
#
# | Falsy | |
# |---|---|
# | `False` | the boolean |
# | `None` | the absence of a value |
# | `0`, `0.0` | any zero number |
# | `""` | the empty string |
# | `[]`, `{}` | an empty list or dictionary |
#
# The pattern behind it: **empty is false, and zero is false**.

# %%
print(bool(0), bool(0.0), bool(""), bool([]), bool(None))
print(bool(1), bool(-5), bool("a"), bool([0]))
# Out:
# False False False False False
# True True True True

# %% [markdown]
# Two of those catch people out, and they are worth looking at twice.

# %%
print(bool(" "))     # a space is a character, so the string is not empty
print(bool("0"))     # the text zero is not the number zero
# Out:
# True
# True

# %% [markdown]
# `bool([0])` is also `True`: a list holding one item is not empty, and it does not matter that
# the item happens to be zero.
#
# This is what `if m:` in the **Regular Expressions** notebook was relying on. A match object is truthy and `None` is
# falsy, so the test reads naturally without mentioning `None` at all.

# %%
name = ""

if name:
    print("got a name")
else:
    print("name is empty")
# Out:
# name is empty

# %% [markdown]
# ### and and or hand back a value, not a boolean
#
# This surprises everyone the first time, and then becomes useful.

# %%
print("" or "default")
print("given" or "default")
print(0 and 99)
print(5 and 99)
# Out:
# default
# given
# 0
# 99

# %% [markdown]
# `or` returns the first thing that is truthy, and `and` returns the first thing that is falsy.
# Neither converts to `True` or `False`.
#
# That gives the common idiom for a fallback:

# %%
user_input = ""
city = user_input or "Philadelphia"

print(city)
# Out:
# Philadelphia

# %% [markdown]
# ### `is` is not `==`
#
# This is where the model from the **Values and Variables** notebook matters. A name is a label on a value, and two labels can be on the
# same value or on two equal values that are not the same object.
#
# - `==` asks **do these have the same value**
# - `is` asks **are these the same object**

# %%
a = [1, 2, 3]
b = [1, 2, 3]     # an equal list, built separately
c = a             # a second label on the same list

print(a == b, "  a and b hold equal values")
print(a is b, "  but they are two different lists")
print(a is c, "   a and c are one list with two names")
# Out:
# True   a and b hold equal values
# False   but they are two different lists
# True    a and c are one list with two names

# %% [markdown]
# `a == b` is `True` and `a is b` is `False`, and both are correct. Change `b` and `a` is
# unaffected; change `c` and `a` changes with it, because there is only one list.

# %%
c.append(4)

print("a:", a)
print("b:", b)
# Out:
# a: [1, 2, 3, 4]
# b: [1, 2, 3]

# %% [markdown]
# Use `==` for almost everything. `is` has one everyday use, and it is the right way to test for
# `None`:

# %%
result = None

print(result is None)
print(result is not None)
# Out:
# True
# False

# %% [markdown]
# Do **not** use `is` on numbers or text. Whether two equal numbers are the same object depends
# on details of the Python build that are not worth learning and can change between versions.
# Recent versions of Python will warn you if you try.
#
# ### in and not in
#
# `in` asks whether something appears inside something else. For text it means a substring.

# %%
city = "Philadelphia"

print("delp" in city)
print("xyz" in city)
print("xyz" not in city)
# Out:
# True
# False
# True

# %% [markdown]
# This is usually clearer than `find(...) != -1` from the **Strings** notebook, and it is the same test.
#
# ### None is a value
#
# `None` means "no value here". It is not zero, and it is not an empty string.

# %%
answer = None

print(answer)
print(type(answer))
print(answer is None, answer == 0, answer == "")
# Out:
# None
# <class 'NoneType'>
# True False False

# %% [markdown]
# It is what a function gives back when it has nothing to return, which the **Functions** notebook covers, and
# what
# `re.search` returned in the **Regular Expressions** notebook when nothing matched.

# %% [markdown]
# ### One oddity worth knowing
#
# `True` and `False` are secretly numbers: `True` is `1` and `False` is `0`.

# %%
print(True + True)
print(sum([True, False, True, True]))
# Out:
# 2
# 3

# %% [markdown]
# That last line is useful. Counting how many things in a collection satisfy a test is
# just adding up the answers, which is a trick that comes back in the **Comprehensions** notebook and again in NumPy.

# %% [markdown]
# ## Your turn
#
# Six tasks. Write your answer in the cell under each and run it.
#
# Try each one before you look at an answer. Reading a solution teaches you much less than
# getting there yourself, even slowly.
#
# When you are ready: [**open the solutions notebook**](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/06-booleans-and-comparison-solutions.ipynb).
#
# **1.** Create `score = 87`. Print `True` or `False` for whether it is between 80 and 90, using
# a chained comparison.

# %%
# your code here

# %% [markdown]
# **2.** Print `bool()` of each of these on separate lines: `0`, `""`, `" "`, `[]`, `"False"`.
# Two of them are true; be sure you can say which before you run it.

# %%
# your code here

# %% [markdown]
# **3.** Create `username = ""`. Using `or`, produce a name that falls back to `"guest"` when
# the username is empty, and print it.

# %%
# your code here

# %% [markdown]
# **4.** Create two equal lists with different names, and a third name pointing at the first
# list. Print the results of `==` and `is` for both pairs.

# %%
# your code here

# %% [markdown]
# **5.** Create `middle_name = None`. Print `"none given"` if it is `None`, using the `is` test
# rather than `==`.

# %%
# your code here

# %% [markdown]
# **6.** Given `words = ["yes", "no", "yes", "yes"]`, count how many are `"yes"` in a single
# line, using the fact that `True` counts as `1`. `sum()` and a comprehension will do it, and
# comprehensions come in the **Comprehensions** notebook, so a loop is fine too.

# %%
# your code here

# %% [markdown]
# ## Common errors
#
# Each cell below is run on purpose so you can see the real message.
#
# ### SyntaxError: one equals sign in a test
#
# Assignment and comparison look similar and mean completely different things.

# %%
x = 5

if x = 5:
    print("five")
# Out:
#   Cell In[26], line 3
#     if x = 5:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# `Maybe you meant '==' or ':=' instead of '='?` is Python telling you exactly what happened. An
# `if` needs a question, and `=` is not a question.
#
# Ignore the `:=` suggestion for now. It is a real operator with a narrow use, and it is not what
# you want here.

# %% [markdown]
# ### TypeError: those two cannot be ordered
#
# `==` works between any two values and simply answers `False` when they differ in type. `<` does
# not.

# %%
print("3" < 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print("3" < 5)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# `'<' not supported between instances of 'str' and 'int'` means Python refuses to guess whether
# you wanted `3 < 5` or `"3" < "5"`. Convert one side yourself.

# %%
print(int("3") < 5)
print("3" < str(5))
# Out:
# True
# True

# %% [markdown]
# Note that `==` across types does not raise; it just says they are different.

# %%
print("3" == 3)
# Out:
# False

# %% [markdown]
# ### The quiet one: comparing floats
#
# This does not raise, which is why it belongs in a list of errors.

# %%
print(0.1 + 0.2 == 0.3)
# Out:
# False

# %% [markdown]
# `False`, for the reason the **Numbers** notebook gave: floats are approximations, and `0.1 + 0.2` lands a
# hair above `0.3`. Nothing here is broken and nothing will warn you.
#
# Compare with a tolerance whenever floats are involved.

# %%
import math

print(math.isclose(0.1 + 0.2, 0.3))
# Out:
# True

# %% [markdown]
# ## Recap
#
# - A comparison produces a boolean, and `==` compares values while `=` assigns.
# - `0 < x < 10` chains, reads like mathematics, and evaluates `x` once.
# - Every value is truthy or falsy: **empty is false and zero is false**, everything else is true.
# - `and` and `or` return one of the operands, which gives the `value or "default"` fallback.
# - `==` asks about value, `is` asks about identity, and `is` is for `None`.
# - `in` tests membership and is clearer than checking `find` against `-1`.
# - `True` is `1`, so `sum()` over a list of tests counts how many passed.

# %% [markdown]
# ## What is next
#
# The **Lists** notebook, the first container: holding many values under one name, and the place
# where mutability from the **Values and Variables** notebook finally gets the treatment it deserves.

# %% [markdown]
# ---
#
# &#8592; **Previous:** [Regular Expressions](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/05-regular-expressions.ipynb)  &nbsp;·&nbsp;  [Python from the Start Notebooks](https://johnfisher-ai.github.io/Python-Visual-Guides/python-from-the-start.html)  &nbsp;·&nbsp;  **Next:** [Lists](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/07-lists.ipynb) &#8594;
