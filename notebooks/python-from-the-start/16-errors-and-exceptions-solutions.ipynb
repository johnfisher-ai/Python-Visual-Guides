# %% [markdown]
# [Python, Visually](https://johnfisher-ai.github.io/Python-Visual-Guides/) &nbsp;&rsaquo;&nbsp; [Python from the Start](https://johnfisher-ai.github.io/Python-Visual-Guides/python-from-the-start.html)
#
# # Errors and Exceptions &middot; Solutions

# %% [markdown]
# One way to do each task. Not the only way. If yours runs and does what was asked, yours is
# right too.

# %% [markdown]
# **1.** Write `safe_int(text)` that returns the number, or `None` if the text is not a
# number.

# %%
def safe_int(text):
    try:
        return int(text)
    except ValueError:
        return None

print(safe_int("7"))
print(safe_int("seven"))
# Out:
# 7
# None

# %% [markdown]
# `except ValueError:` names the one failure expected here. A different problem would still
# reach you as a traceback.

# %% [markdown]
# **2.** Rewrite it to print the exception message before returning `None`, using `as`.

# %%
def safe_int(text):
    try:
        return int(text)
    except ValueError as e:
        print("could not convert:", e)
        return None

print(safe_int("seven"))
# Out:
# could not convert: invalid literal for int() with base 10: 'seven'
# None

# %% [markdown]
# The message is the same text a traceback would have shown, which is what makes it worth
# printing rather than inventing your own wording.

# %% [markdown]
# **3.** Write a function that divides two numbers and handles both a non-numeric input and a
# zero divisor, with a different message for each.

# %%
def divide(text, divisor):
    try:
        return int(text) / divisor
    except ValueError:
        return "not a number"
    except ZeroDivisionError:
        return "cannot divide by zero"

print(divide("10", 2))
print(divide("ten", 2))
print(divide("10", 0))
# Out:
# 5.0
# not a number
# cannot divide by zero

# %% [markdown]
# Two `except` blocks, each naming one type. Order does not matter here because `ValueError` and
# `ZeroDivisionError` are unrelated, but putting the specific case first is the habit worth
# keeping.

# %% [markdown]
# **4.** Given `ages = {"ada": 36}`, look up `"grace"` and print `"not on file"` instead of
# raising.

# %%
ages = {"ada": 36}

try:
    print(ages["grace"])
except KeyError:
    print("not on file")
# Out:
# not on file

# %% [markdown]
# `.get()` from the **Dictionaries** notebook does the same job in one line:

# %%
print(ages.get("grace", "not on file"))
# Out:
# not on file

# %% [markdown]
# Use `.get()` when a miss is ordinary. Use `try` and `except KeyError` when a miss means
# something has gone wrong and you want to handle it deliberately.

# %% [markdown]
# **5.** Write `withdraw(balance, amount)` that raises `ValueError` when the amount is more
# than the balance.

# %%
def withdraw(balance, amount):
    if amount > balance:
        raise ValueError(f"cannot withdraw {amount} from a balance of {balance}")
    return balance - amount

print(withdraw(100, 30))
# Out:
# 70

# %%
print(withdraw(100, 300))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(withdraw(100, 300))
#
# Cell In[6], line 3, in withdraw(balance, amount)
#       1 def withdraw(balance, amount):
#       2     if amount > balance:
# ----> 3         raise ValueError(f"cannot withdraw {amount} from a balance of {balance}")
#       4     return balance - amount
#
# ValueError: cannot withdraw 300 from a balance of 100

# %% [markdown]
# The message names both numbers, so whoever reads the traceback does not have to go looking for
# what the values were. Returning `None` or `0` instead would have let the program carry on with a
# wrong balance.

# %% [markdown]
# **6.** Given `values = ["3", "4", "x", "5"]`, total the ones that are numbers and print
# how many were skipped.

# %%
values = ["3", "4", "x", "5"]

total = 0
skipped = 0
for v in values:
    try:
        total += int(v)
    except ValueError:
        skipped += 1

print("total:", total)
print("skipped:", skipped)
# Out:
# total: 12
# skipped: 1

# %% [markdown]
# Counting what was skipped is the part worth keeping. A loop that silently drops bad values gives
# an answer with no indication of how much of the data it is based on.

# %% [markdown]
# ---
#
# &#8592; **Back to:** [Errors and Exceptions](https://colab.research.google.com/github/johnfisher-ai/Python-Visual-Guides/blob/main/notebooks/python-from-the-start/16-errors-and-exceptions.ipynb)  &nbsp;&middot;&nbsp;  [Python from the Start Notebooks](https://johnfisher-ai.github.io/Python-Visual-Guides/python-from-the-start.html)
